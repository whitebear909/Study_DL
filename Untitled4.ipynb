# %%
import pandas as pd

# %%
get_wd()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-de20ea537354> in <module>
# ----> 1 get_wd()
#
# NameError: name 'get_wd' is not defined

# %%
df = pd.read_csv("D:/test2.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3666 entries, 0 to 3665
# Data columns (total 16 columns):
# productName              3666 non-null object
# serviceName              3666 non-null object
# createdSecondDate        3666 non-null object
# osVersion                3528 non-null object
# channel                  3666 non-null object
# ioCode                   3666 non-null object
# text                     3653 non-null object
# intent                   1734 non-null object
# confidence               1532 non-null float64
# updater                  3666 non-null object
# unsigned                 3647 non-null object
# conversationId           3666 non-null object
# productId                3666 non-null int64
# serviceId                3666 non-null int64
# conversationTime         3666 non-null object
# groupConversationTime    3666 non-null object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 458.3+ KB

# %%
df.head(1)
df = df.drop(labels = ['productName','serviceName', 'osVersion', 'channel'], axis = 1)

# %%
df.head(1)
# Out:
#   createdSecondDate ioCode                                               text  \
# 0  2019-04-02 11:12      O  안녕하세요? 판토스 챗봇입니다.<br>무엇을 도와드릴까요?<br>아래 버튼을 클릭해...
#
#   intent  confidence updater unsigned                        conversationId  \
# 0    NaN         NaN   admin      NaN  e4228203-c8bb-4c30-8c94-2a10e0acc1ad
#
#    productId  serviceId  conversationTime groupConversationTime
# 0      10002      10002  2019-04-02 11:12      2019-04-02 11:12

# %%
df.serviceId.value_counts()
# Out:
# 10002    3666
# Name: serviceId, dtype: int64

# %%
df = df.drop(labels = ['serviceId','productId'], axis = 1)

# %%
df['conversationTime'] = pd.to_datetime(df['conversationTime'])

# %%
df['groupConversationTime'] = pd.to_datetime(df['groupConversationTime'])

# %%
df['createdSecondDate'] = pd.to_datetime(df['createdSecondDate'])

# %%
df.head()
# Out:
#     createdSecondDate ioCode  \
# 0 2019-04-02 11:12:00      O
# 1 2019-04-02 11:12:00      I
# 2 2019-04-02 11:12:00      O
# 3 2019-04-02 11:12:00      O
# 4 2019-04-09 13:27:00      O
#
#                                                 text intent  confidence  \
# 0  안녕하세요? 판토스 챗봇입니다.<br>무엇을 도와드릴까요?<br>아래 버튼을 클릭해...    NaN         NaN
# 1                                                정수기    NaN         NaN
# 2            전자제품 관련하여 제가 안내 해 드릴 수 있는 내용은 다음과 같습니다.    NaN         NaN
# 3  안녕하세요? 판토스 챗봇입니다.<br>무엇을 도와드릴까요?<br>아래 버튼을 클릭해...    NaN         NaN
# 4  안녕하세요? 판토스 챗봇입니다.<br>무엇을 도와드릴까요?<br>아래 버튼을 클릭해...    NaN         NaN
#
#   updater unsigned                        conversationId    conversationTime  \
# 0   admin      NaN  e4228203-c8bb-4c30-8c94-2a10e0acc1ad 2019-04-02 11:12:00
# 1   admin      NaN  e4228203-c8bb-4c30-8c94-2a10e0acc1ad 2019-04-02 11:12:00
# 2   admin      NaN  e4228203-c8bb-4c30-8c94-2a10e0acc1ad 2019-04-02 11:12:00
# ...

# %%
pd.concat([df['conversationId'], df['conversationTime']], axis = 1)
# Out:
#                             conversationId    conversationTime
# 0     e4228203-c8bb-4c30-8c94-2a10e0acc1ad 2019-04-02 11:12:00
# 1     e4228203-c8bb-4c30-8c94-2a10e0acc1ad 2019-04-02 11:12:00
# 2     e4228203-c8bb-4c30-8c94-2a10e0acc1ad 2019-04-02 11:12:00
# 3     b60fa5fa-7404-4f1f-b41b-f10194301ed1 2019-04-02 11:12:00
# 4     136c9f8e-5a60-45fe-b7f5-21e3601c7485 2019-04-09 13:27:00
# 5     136c9f8e-5a60-45fe-b7f5-21e3601c7485 2019-04-09 13:27:00
# 6     136c9f8e-5a60-45fe-b7f5-21e3601c7485 2019-04-09 13:27:00
# 7     ec78ba58-c5f9-4c27-9c95-c0cd2978ebdf 2019-04-12 08:59:00
# 8     ec78ba58-c5f9-4c27-9c95-c0cd2978ebdf 2019-04-12 08:59:00
# 9     ec78ba58-c5f9-4c27-9c95-c0cd2978ebdf 2019-04-12 08:59:00
# 10    116c87ae-8c7b-4e64-aeae-4d2f9ff20cdb 2019-04-17 13:33:00
# 11    116c87ae-8c7b-4e64-aeae-4d2f9ff20cdb 2019-04-17 13:33:00
# 12    116c87ae-8c7b-4e64-aeae-4d2f9ff20cdb 2019-04-17 13:33:00
# 13    116c87ae-8c7b-4e64-aeae-4d2f9ff20cdb 2019-04-17 13:33:00
# ...

# %%
df.loc[df['conversationTime'] == df.groupby('conversationId')['conversationTime'].min(),:]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-72577d9e3038> in <module>
# ----> 1 df.loc[df['conversationTime'] == df.groupby('conversationId')['conversationTime'].min(),:]
#
# ~\AppData\Local\Continuum\anaconda364\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1674
#    1675         elif isinstance(other, ABCSeries) and not self._indexed_same(other):
# -> 1676             raise ValueError("Can only compare identically-labeled "
#    1677                              "Series objects")
#    1678
#
# ValueError: Can only compare identically-labeled Series objects

# %%
delete.str.split()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-3ac284f6573a> in <module>
# ----> 1 delete.str.split()
#
# ~\AppData\Local\Continuum\anaconda364\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\AppData\Local\Continuum\anaconda364\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     169             # we're accessing the attribute of the class, i.e., Dataset.geo
#     170             return self._accessor
# --> 171         accessor_obj = self._accessor(obj)
# ...

# %%
df[seq] = pd.Serises[range(len(df))]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-eaead348a09c> in <module>
# ----> 1 df[seq] = pd.Serises[range(len(df))]
#
# AttributeError: module 'pandas' has no attribute 'Serises'

# %%
df.head()
# Out:
#   createdSecondDate ioCode                                               text  \
# 0  2019-04-02 11:12      O  안녕하세요? 판토스 챗봇입니다.<br>무엇을 도와드릴까요?<br>아래 버튼을 클릭해...
# 1  2019-04-02 11:12      I                                                정수기
# 2  2019-04-02 11:12      O            전자제품 관련하여 제가 안내 해 드릴 수 있는 내용은 다음과 같습니다.
# 3  2019-04-02 11:12      O  안녕하세요? 판토스 챗봇입니다.<br>무엇을 도와드릴까요?<br>아래 버튼을 클릭해...
# 4  2019-04-09 13:27      O  안녕하세요? 판토스 챗봇입니다.<br>무엇을 도와드릴까요?<br>아래 버튼을 클릭해...
#
#   intent  confidence updater unsigned                        conversationId  \
# 0    NaN         NaN   admin      NaN  e4228203-c8bb-4c30-8c94-2a10e0acc1ad
# 1    NaN         NaN   admin      NaN  e4228203-c8bb-4c30-8c94-2a10e0acc1ad
# 2    NaN         NaN   admin      NaN  e4228203-c8bb-4c30-8c94-2a10e0acc1ad
# 3    NaN         NaN   admin      NaN  b60fa5fa-7404-4f1f-b41b-f10194301ed1
# 4    NaN         NaN  haniln      NaN  136c9f8e-5a60-45fe-b7f5-21e3601c7485
#
# ...
