# %%
import pytagcloud
import random

# %%
import webbrowser

# %%
from konlpy.tag import Okt

# %%
from collections import Counter

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
import matplotlib.font_manager as fm

# %%
file = open('d:/april.txt','r',encoding='utf-8')

# %%
lines = file.readlines()

# %%
okja = []

# %%
for line in lines:
    okja.append(line)

# %%
file.close()

# %%
# 3. 트윗터 패키지 안에 konlpy 모듈호출

# %%
twitter = Okt()

# %%
# 4. 각 문장별로 형태소 구분하기
sentences_tag = []
for sentence in okja:
    morph = twitter.pos(sentence)
    sentences_tag.append(morph)
    print(morph)
    print('-'*30)

print(sentences_tag)
print(len(sentences_tag))
print('\n'*3)
# Out:
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('메일', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('한국', 'Noun'), ('글로벌', 'Noun'), ('네트워크', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('글로벌', 'Noun'), ('네트워크', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('오산', 'Noun'), ('센터', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('국제', 'Noun'), ('특송', 'Noun'), ('/', 'Punctuation'), ('E', 'Alpha'), ('-', 'Punctuation'), ('Commerce', 'Alpha'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('Construction', 'Alpha'), ('&', 'Punctuation'), ('Machinery', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('해상', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('물류', 'Noun'), ('SCM', 'Alpha'), ('컨설팅', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('철거', 'Noun'), ('만', 'Josa'), ('신청', 'Noun'), ('하면', 'Verb'), ('아파트', 'Noun'), ('주차장', 'Noun'), ('으로', 'Josa'), ('내려주나요', 'Verb'), ('?', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('철거', 'Noun'), ('만', 'Josa'), ('신청', 'Noun'), ('하면', 'Verb'), ('아파트', 'Noun'), ('주차장', 'Noun'), ('으로', 'Josa'), ('내려주나요', 'Verb'), ('?', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('건조기', 'Noun'), ('이전', 'Noun'), ('설치', 'Noun'), ('비용', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('예', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('해상', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('사업', 'Noun'), ('영역', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('판', 'Noun'), ('토스', 'Noun'), ('성장', 'Noun'), ('과정', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('이전', 'Noun'), ('설치', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('e', 'Alpha'), ('판', 'Noun'), ('토스', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('송장', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('브라켓', 'Noun'), ('이', 'Josa'), ('없습니다', 'Adjective'), ('\n', 'Foreign')]
# ------------------------------
# [('32', 'Number'), ('LK', 'Alpha'), ('562', 'Number'), ('BENA', 'Alpha'), ('스탠드', 'Noun'), ('형', 'Suffix'), ('을', 'Josa'), ('새로', 'Adjective'), ('샀는데', 'Verb'), ('벽', 'Noun'), ('걸이', 'Noun'), ('로', 'Josa'), ('걸수있나요', 'Verb'), ('\n', 'Foreign')]
# ------------------------------
# [('배송', 'Noun'), ('조회', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('채용', 'Noun'), ('페이지', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('면접', 'Noun'), ('관', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('IT', 'Alpha'), ('솔루션', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('채용', 'Noun'), ('페이지', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('배송', 'Noun'), ('조회', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('채용', 'Noun'), ('페이지', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('배송', 'Noun'), ('조회', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('배송', 'Noun'), ('조회', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('PLIHQ', 'Alpha'), ('2', 'Number'), ('A', 'Alpha'), ('18674', 'Number'), ('\n', 'Foreign')]
# ------------------------------
# [('lg', 'Alpha'), ('전자', 'Noun'), ('이전', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('채용', 'Noun'), ('페이지', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('해상', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('항공', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('항공', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('아니오', 'Adjective'), ('\n', 'Foreign')]
# ------------------------------
# [('Best', 'Alpha'), ('Practice', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('02-3771', 'Number'), ('-', 'Punctuation'), ('3974', 'Number'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('Electronics', 'Alpha'), ('&', 'Punctuation'), ('Hi', 'Alpha'), ('-', 'Punctuation'), ('Tech', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('예', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('예', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('중국', 'Noun'), ('글로벌', 'Noun'), ('네트워크', 'Noun'), ('안내', 'Noun')]
# ------------------------------
# [('글로벌', 'Noun'), ('네트워크', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('이전', 'Noun'), ('설치', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('식기세척기', 'Noun'), ('설치', 'Noun'), ('신청', 'Noun'), ('합니다', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('항공', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('해상', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('정수기', 'Noun'), ('이전', 'Noun'), ('설치', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('lg', 'Alpha'), ('가전제품', 'Noun'), ('이', 'Determiner'), ('전', 'Modifier'), ('설치', 'Noun'), ('에', 'Josa'), ('대해', 'Noun'), ('서', 'Josa'), ('문의', 'Noun'), ('드릴', 'Noun'), ('게', 'Josa'), ('있습니다', 'Adjective'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('도움말', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('항공', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('벽', 'Noun'), ('걸이', 'Noun'), ('설치', 'Noun'), ('비용', 'Noun'), ('은', 'Josa'), ('47,000원', 'Number'), ('이라', 'Foreign'), ('나와', 'Verb'), ('있는데', 'Adjective'), ('자재', 'Noun'), ('값', 'Noun'), ('포함', 'Noun'), ('인가요', 'Josa'), ('?', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('이사', 'Noun'), ('가서', 'Verb'), ('32', 'Number'), ('인치', 'Noun'), ('티브', 'Noun'), ('를', 'Josa'), ('벽', 'Noun'), ('걸이', 'Noun'), ('로', 'Josa'), ('하려', 'Verb'), ('합니다', 'Verb'), ('\n', 'Foreign')]
# ------------------------------
# [('안녕하세요', 'Adjective'), ('~', 'Punctuation'), ('저희', 'Noun'), ('가', 'Josa'), ('이사', 'Noun'), ('를', 'Josa'), ('앞', 'Noun'), ('두고', 'Verb'), ('있는데', 'Adjective'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('사업', 'Noun'), ('영역', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('Project', 'Alpha'), ('Cargo', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('철도', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('사업', 'Noun'), ('영역', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('전자상거래', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('야', 'Exclamation'), ('\n', 'Foreign')]
# ------------------------------
# [('화물', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('택배', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('급행', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('급행', 'Noun'), ('화물', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('Express', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('항공', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('해상', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('컨테이너', 'Noun'), ('서비스', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('성공사례', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('판', 'Noun'), ('토스', 'Noun'), ('국제', 'Noun'), ('물류', 'Noun'), ('센터', 'Noun'), ('물류', 'Noun'), ('정보', 'Noun'), ('효율', 'Noun'), ('화', 'Suffix'), ('활동', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('채용', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('아니오', 'Adjective'), ('\n', 'Foreign')]
# ------------------------------
# [('scm', 'Alpha'), ('전략', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('글로벌', 'Noun'), ('네트워크', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('글로벌', 'Noun'), ('네트워크', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('채용', 'Noun'), ('페이지', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('고객', 'Noun'), ('센터', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('김치냉장고', 'Noun'), ('와', 'Josa'), ('17', 'Number'), ('kg', 'Alpha'), ('트롬', 'Noun'), ('세탁기', 'Noun'), ('를', 'Josa'), ('같이', 'Adverb'), ('철거', 'Noun'), ('이', 'Determiner'), ('전', 'Modifier'), ('설치', 'Noun'), ('할', 'Verb'), ('경우', 'Noun'), ('비용', 'Noun'), ('이', 'Josa'), ('얼마', 'Noun'), ('인가요', 'Josa'), ('?', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('세탁기', 'Noun'), ('옮기는데', 'Verb'), ('얼마', 'Noun'), ('니', 'Josa'), ('\n', 'Foreign')]
# ------------------------------
# [('너', 'Noun'), ('는', 'Josa'), ('몇', 'Modifier'), ('살이', 'Noun'), ('야', 'Josa'), ('\n', 'Foreign')]
# ------------------------------
# [('나도', 'Verb'), ('알', 'Noun'), ('아', 'Josa'), ('\n', 'Foreign')]
# ------------------------------
# [('너', 'Noun'), ('는', 'Josa'), ('누구', 'Noun'), ('니', 'Josa'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('해상', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('해상', 'Noun'), ('운임', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('인도네시아', 'Noun'), ('자카르타', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('예', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('인도네시아', 'Noun'), ('자카르타', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('통관', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('판', 'Noun'), ('토스', 'Noun'), ('이메일', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('배송', 'Noun'), ('조회', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('예', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('안녕하세요', 'Adjective'), ('해외', 'Noun'), ('에서', 'Josa'), ('직구', 'Noun'), ('한', 'Josa'), ('물품', 'Noun'), ('의', 'Josa'), ('국내', 'Noun'), ('항공', 'Noun'), ('도착', 'Noun'), ('시간', 'Noun'), ('이', 'Josa'), ('궁금합니다', 'Adjective'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('미국', 'Noun'), ('아마존', 'Noun'), ('으로', 'Josa'), ('배송', 'Noun'), ('하고', 'Josa'), ('싶어요', 'Verb'), ('\n', 'Foreign')]
# ------------------------------
# [('인보이스', 'Noun'), ('수정', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('적하', 'Noun'), ('정정', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('GSI', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('lg', 'Alpha'), ('전자제품', 'Noun'), ('이전', 'Noun'), ('설치', 'Noun'), ('비용', 'Noun'), ('문의', 'Noun'), ('요', 'Josa'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('에어컨', 'Noun'), ('추가', 'Noun'), ('설치', 'Noun'), ('비용', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('PLIHQ', 'Alpha'), ('2', 'Number'), ('A', 'Alpha'), ('23314', 'Number'), ('\n', 'Foreign')]
# ------------------------------
# [('해상', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('프로젝트', 'Noun'), ('물류', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('예', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('인도네시아', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('예', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('아시아', 'Noun'), ('글로벌', 'Noun'), ('네트워크', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('글로벌', 'Noun'), ('네트워크', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('tv', 'Alpha'), ('이전', 'Noun'), ('설치', 'Noun'), ('문의', 'Noun'), ('할려', 'Verb'), ('구', 'Noun'), ('요', 'Josa'), ('\n', 'Foreign')]
# ------------------------------
# [('오시', 'Noun'), ('는', 'Josa'), ('길', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('채용', 'Noun'), ('페이지', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('이사', 'Noun'), ('로', 'Josa'), ('인해서', 'Adjective'), ('퓨리', 'Noun'), ('케어', 'Noun'), ('정수기', 'Noun'), ('이전', 'Noun'), ('설치', 'Noun'), ('신청', 'Noun'), ('하려고', 'Verb'), ('합니다', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('일요일', 'Noun'), ('설치', 'Noun'), ('해요', 'Verb'), ('?', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회원', 'Noun'), ('가입', 'Noun'), ('은', 'Josa'), ('어디서', 'Adverb'), ('하나요', 'Noun'), ('?', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('fns', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('FNS', 'Alpha'), ('와', 'Verb'), ('판', 'Noun'), ('토스', 'Noun'), ('는', 'Josa'), ('무슨', 'Noun'), ('관계', 'Noun'), ('인가요', 'Josa'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('W', 'Alpha'), ('&', 'Punctuation'), ('d', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('예', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('통관', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('궁금해서', 'Adjective'), ('연락', 'Noun'), ('드립니다', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('다름이', 'Adjective'), ('아니오라', 'Adjective'), ('통관', 'Noun'), ('이', 'Josa'), ('되었는지', 'Verb'), ('\n', 'Foreign')]
# ------------------------------
# [('안녕하세요', 'Adjective'), ('\n', 'Foreign')]
# ------------------------------
# [('전자제품', 'Noun'), ('설치', 'Noun'), ('물류', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('IT', 'Alpha'), ('솔루션', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('해상', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('사업', 'Noun'), ('영역', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('판', 'Noun'), ('토스', 'Noun'), ('란', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('판', 'Noun'), ('토스', 'Noun'), ('의', 'Josa'), ('뜻', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('판', 'Noun'), ('토스', 'Noun'), ('의', 'Josa'), ('의미', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('ci', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('예', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('미국', 'Noun'), ('으로', 'Josa'), ('명품', 'Noun'), ('화장품', 'Noun'), ('통관', 'Noun'), ('이', 'Josa'), ('가능한가요', 'Adjective'), ('?', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('안녕하세요', 'Adjective'), ('\n', 'Foreign')]
# ------------------------------
# [('북미', 'Noun'), ('글로벌', 'Noun'), ('네트워크', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('글로벌', 'Noun'), ('네트워크', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('장성', 'Noun'), ('용', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('장성', 'Noun'), ('용', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('Warehouse', 'Alpha'), ('(', 'Punctuation'), ('창고', 'Noun'), ('운영', 'Noun'), (')', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('W', 'Alpha'), ('&', 'Punctuation'), ('D', 'Alpha'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('예', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('예', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('베트남', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('예', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('아시아', 'Noun'), ('글로벌', 'Noun'), ('네트워크', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('글로벌', 'Noun'), ('네트워크', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('LG', 'Alpha'), ('전자', 'Noun'), ('이전', 'Noun'), ('설치', 'Noun'), ('신청', 'Noun'), ('했습니다', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('사보', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('채용', 'Noun'), ('페이지', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('삼자', 'Noun'), ('물류', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('프로젝트', 'Noun'), ('물류', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('사업', 'Noun'), ('영역', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('IT', 'Alpha'), ('솔루션', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('안녕하세요', 'Adjective'), ('.', 'Punctuation'), ('LG', 'Alpha'), ('가전', 'Noun'), ('이전', 'Noun'), ('설치', 'Noun'), ('신청', 'Noun'), ('했는데', 'Verb'), (',', 'Punctuation'), ('사다리', 'Noun'), ('차', 'Noun'), ('비용', 'Noun'), ('문의', 'Noun'), ('드립니다', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('정수기', 'Noun'), ('이전', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('미국', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('삼국', 'Noun'), ('간', 'Suffix'), ('\n', 'Foreign')]
# ------------------------------
# [('프로젝트', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('해상', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('수입', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('IT', 'Alpha'), ('솔루션', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('Electronics', 'Alpha'), ('&', 'Punctuation'), ('Hi', 'Alpha'), ('-', 'Punctuation'), ('Tech', 'Alpha'), ('레퍼런스', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('정수기', 'Noun'), ('철거', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('안녕하세요', 'Adjective'), ('.', 'Punctuation'), ('정수기', 'Noun'), ('철거', 'Noun'), ('신청', 'Noun'), ('어떻게', 'Adjective'), ('하나요', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('해상', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('유럽', 'Noun'), ('글로벌', 'Noun'), ('네트워크', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('글로벌', 'Noun'), ('네트워크', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('채용', 'Noun'), ('페이지', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('ㅗㅗㅗ', 'KoreanParticle'), ('\n', 'Foreign')]
# ------------------------------
# [('바보', 'Noun'), ('야', 'Josa'), ('\n', 'Foreign')]
# ------------------------------
# [('야', 'Exclamation'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('판', 'Noun'), ('토스', 'Noun'), ('챗봇', 'Noun'), ('아', 'Josa'), ('자폭', 'Noun'), ('해', 'Verb'), ('\n', 'Foreign')]
# ------------------------------
# [('해상', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('사업', 'Noun'), ('영역', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('배', 'Noun'), ('의', 'Josa'), ('원리', 'Noun'), ('는', 'Josa'), ('?', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('컨테이너', 'Noun'), ('장점', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('해상', 'Noun'), ('운송', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('수', 'Modifier'), ('출시', 'Noun'), ('컨테이너', 'Noun'), ('를', 'Josa'), ('사용', 'Noun'), ('하면', 'Verb'), ('좋은', 'Adjective'), ('점', 'Noun'), ('이', 'Josa'), ('무엇', 'Noun'), ('인가요', 'Josa'), ('?', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('해상', 'Noun'), ('누송', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('order', 'Alpha'), ('register', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('스켸줄', 'Noun'), ('조회', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('Construction', 'Alpha'), ('&', 'Punctuation'), ('Machinery', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('국제', 'Noun'), ('특송', 'Noun'), ('/', 'Punctuation'), ('E', 'Alpha'), ('-', 'Punctuation'), ('Commerce', 'Alpha'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('항공', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('채용', 'Noun'), ('페이지', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('아니오', 'Adjective'), ('\n', 'Foreign')]
# ------------------------------
# [('통관', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('사업', 'Noun'), ('영역', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('배송', 'Noun'), ('조회', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('판', 'Noun'), ('토스', 'Noun'), ('챗봇', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('하하', 'Noun'), ('하', 'Suffix'), ('\n', 'Foreign')]
# ------------------------------
# [('테스트', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('채채', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('판톳그', 'Noun'), ('챗봄', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('챗봇', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('하하', 'Noun'), ('하', 'Suffix'), ('\n', 'Foreign')]
# ------------------------------
# [('판', 'Noun'), ('토스', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('파놑스', 'Noun')]
# ------------------------------
# [('판', 'Noun'), ('토스', 'Noun'), ('챗봇', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('전자제품', 'Noun'), ('설치', 'Noun'), ('물류', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('65', 'Number'), ('UJ', 'Alpha'), ('6600', 'Number'), (',', 'Punctuation'), ('SmartLED', 'Alpha'), (',', 'Punctuation'), ('163', 'Number'), ('cm', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('브라켓', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('배송', 'Noun'), ('조회', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('벽', 'Noun'), ('걸이', 'Noun'), ('설치', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('정수기', 'Noun'), ('이전', 'Noun'), ('설치', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('IT', 'Alpha'), ('솔루션', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('이사', 'Noun'), ('했는데', 'Verb'), ('식기세척기', 'Noun'), ('는', 'Josa'), ('이전', 'Noun'), ('설치', 'Noun'), ('안', 'VerbPrefix'), ('해주나요', 'Verb'), ('?', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('식기세척기', 'Noun'), ('설치', 'Noun'), ('하려고', 'Verb'), ('하는데요', 'Verb'), ('선택', 'Noun'), ('제품군', 'Noun'), ('에', 'Josa'), ('없네요', 'Adjective'), ('?', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('Electronics', 'Alpha'), ('&', 'Punctuation'), ('Hi', 'Alpha'), ('-', 'Punctuation'), ('Tech', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('예', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('싱가폴', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('예', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('아시아', 'Noun'), ('글로벌', 'Noun'), ('네트워크', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('글로벌', 'Noun'), ('네트워크', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('유럽', 'Noun'), ('글로벌', 'Noun'), ('네트워크', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('예', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('베네룩스', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('예', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('물류', 'Noun'), ('SCM', 'Alpha'), ('컨설팅', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('예', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('베네룩스', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('예', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('유럽', 'Noun'), ('글로벌', 'Noun'), ('네트워크', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('글로벌', 'Noun'), ('네트워크', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('tracking', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('채용', 'Noun'), ('페이지', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('이우진', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('Electronics', 'Alpha'), ('&', 'Punctuation'), ('Hi', 'Alpha'), ('-', 'Punctuation'), ('Tech', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('구미', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('Chemical', 'Alpha'), ('&', 'Punctuation'), ('Oil', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('프로젝트', 'Noun'), ('물류', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('프로젝트', 'Noun'), ('물류', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('전자제품', 'Noun'), ('설치', 'Noun'), ('물류', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('철도', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('김성주', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('Warehouse', 'Alpha'), ('(', 'Punctuation'), ('창고', 'Noun'), ('운영', 'Noun'), (')', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('W', 'Alpha'), ('&', 'Punctuation'), ('D', 'Alpha'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('저수조', 'Noun'), ('있는', 'Adjective'), ('냉정', 'Noun'), ('수기', 'Noun'), ('예요', 'Josa'), ('\n', 'Foreign')]
# ------------------------------
# [('정수기', 'Noun'), ('철거', 'Noun'), ('와', 'Josa'), ('운송', 'Noun'), ('해놓았어요', 'Verb'), ('설치시', 'Adjective'), ('비용', 'Noun'), ('은', 'Josa'), ('얼마', 'Noun'), ('인가요', 'Josa'), ('?', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('사내', 'Noun'), ('이사', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('경쟁', 'Noun'), ('사', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('2018년', 'Number'), ('매출', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('물류', 'Noun'), ('매출', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('화', 'Noun'), ('주사', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('IR', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('FNS', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('박봉', 'Noun'), ('철', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('cis', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('Vekaterinburg', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('343251447404', 'Number'), ('\n', 'Foreign')]
# ------------------------------
# [('배송', 'Noun'), ('조회', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('글로벌', 'Noun'), ('네트워크', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('IT', 'Alpha'), ('솔루션', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('채용', 'Noun'), ('페이지', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('Electronics', 'Alpha'), ('&', 'Punctuation'), ('Hi', 'Alpha'), ('-', 'Punctuation'), ('Tech', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('베네룩스', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('예', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('유럽', 'Noun'), ('글로벌', 'Noun'), ('네트워크', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('글로벌', 'Noun'), ('네트워크', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('Auto', 'Alpha'), ('Parts', 'Alpha'), ('&', 'Punctuation'), ('Tire', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('Auto', 'Alpha'), ('Parts', 'Alpha'), ('&', 'Punctuation'), ('Tire', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('2019년', 'Number'), ('4월', 'Number'), ('16일', 'Number'), ('0시', 'Number'), ('에', 'Foreign'), ('발송', 'Noun'), ('을', 'Josa'), ('했으면', 'Verb'), ('\n', 'Foreign')]
# ------------------------------
# [('배송', 'Noun'), ('조회', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('해외', 'Noun'), ('직구', 'Noun'), ('물품', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('배송', 'Noun'), ('확인', 'Noun'), ('방법', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('졸업', 'Noun'), ('예', 'Modifier'), ('쩡', 'Noun'), ('자', 'Suffix'), ('채용', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('고', 'Modifier'), ('졸', 'Noun'), ('채용', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('W', 'Alpha'), ('&', 'Punctuation'), ('D', 'Alpha'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('사업', 'Noun'), ('영역', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('비전', 'Verb'), ('\n', 'Foreign')]
# ------------------------------
# [('국제', 'Noun'), ('특송', 'Noun'), ('/', 'Punctuation'), ('E', 'Alpha'), ('-', 'Punctuation'), ('Commerce', 'Alpha'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('조직', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('조직', 'Noun'), ('도', 'Josa'), ('\n', 'Foreign')]
# ------------------------------
# [('항공', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('항공', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('Chemical', 'Alpha'), ('&', 'Punctuation'), ('Oil', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('고객', 'Noun'), ('사', 'Noun'), ('사례', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('해상', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('IT', 'Alpha'), ('솔루션', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('말레이시아', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('필리핀', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('싱가폴', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('인도네시아', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('일본', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('미국', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('말레이시아', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('말레이시아', 'Noun'), ('법인', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('예', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('아시아', 'Noun'), ('글로벌', 'Noun'), ('네트워크', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('말레이시아', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('채용', 'Noun'), ('페이지', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('IT', 'Alpha'), ('솔루션', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('Electronics', 'Alpha'), ('&', 'Punctuation'), ('Hi', 'Alpha'), ('-', 'Punctuation'), ('Tech', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('시스템', 'Noun'), ('링크', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('최근', 'Noun'), ('이슈', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('해상', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('IT', 'Alpha'), ('솔루션', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('절차', 'Noun'), ('가', 'Josa'), ('어떻게', 'Adjective'), ('되는지', 'Verb'), ('궁금합니다', 'Adjective'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('안녕하세요', 'Adjective'), ('.', 'Punctuation'), ('혹시', 'Noun'), ('판', 'Noun'), ('토스', 'Noun'), ('인천', 'Noun'), ('물류', 'Noun'), ('센터', 'Noun'), ('견학', 'Noun'), ('을', 'Josa'), ('신청', 'Noun'), ('하고', 'Josa'), ('싶은데', 'Verb'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('채용', 'Noun'), ('페이지', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('국제', 'Noun'), ('특송', 'Noun'), ('/', 'Punctuation'), ('E', 'Alpha'), ('-', 'Punctuation'), ('Commerce', 'Alpha'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('사훈', 'Noun'), ('은', 'Josa'), ('?', 'Punctuation'), ('\n', 'Foreign')]
# ...
# [('정수기', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('채용', 'Noun'), ('페이지', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('전자제품', 'Noun'), ('설치', 'Noun'), ('물류', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('브로', 'Noun'), ('셔', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('전자제품', 'Noun'), ('설치', 'Noun'), ('및', 'Noun'), ('이전', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('정수기', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('대표이사', 'Noun'), ('사장', 'Noun'), ('은', 'Josa'), ('?', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('한국', 'Noun'), ('글로벌', 'Noun'), ('네트워크', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('지역', 'Noun'), ('무류', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('로그인', 'Noun'), ('방법', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('로그인', 'Noun'), ('방버', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('채용', 'Noun'), ('페이지', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('전자제품', 'Noun'), ('설치', 'Noun'), ('및', 'Noun'), ('이전', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('정수기', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('이전', 'Noun'), ('설치', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('별', 'Modifier'), ('점', 'Noun'), ('5', 'Number'), ('점', 'Noun'), (',', 'Punctuation'), ('등록', 'Noun'), ('되었습니다', 'Verb'), ('\n', 'Foreign')]
# ------------------------------
# [('감사합니다', 'Verb'), ('.', 'Punctuation')]
# ------------------------------
# [('예', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('lg', 'Alpha'), ('전자', 'Noun'), ('건조기', 'Noun'), ('를', 'Josa'), ('구입', 'Noun'), ('했는데', 'Verb'), ('언제', 'Noun'), ('배송', 'Noun'), ('되나요', 'Verb'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('Chemical', 'Alpha'), ('&', 'Punctuation'), ('Oil', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('IT', 'Alpha'), ('솔루션', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('예', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('관세', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('관세사', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('채용', 'Noun'), ('페이지', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('글로벌', 'Noun'), ('네트워크', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('채용', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('배송', 'Noun'), ('조회', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('송장', 'Noun'), ('번호', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('invoice', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('3', 'Number'), ('pl', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('아니오', 'Adjective'), ('\n', 'Foreign')]
# ------------------------------
# [('물류', 'Noun'), ('SCM', 'Alpha'), ('컨설팅', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('사업', 'Noun'), ('영역', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('IT', 'Alpha'), ('솔루션', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('냉장고', 'Noun'), ('설치', 'Noun'), ('문의', 'Noun'), ('입니다', 'Adjective'), ('.', 'Punctuation')]
# ------------------------------
# [('제품', 'Noun'), ('설치', 'Noun'), ('문의', 'Noun'), ('해도', 'Verb'), ('되나요', 'Verb'), ('>', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('엠블럼', 'Noun'), ('다운로드', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('정수기', 'Noun'), ('는', 'Josa'), ('어떻게', 'Adjective'), ('설치', 'Noun'), ('신청', 'Noun'), ('하죠', 'Verb'), ('\n', 'Foreign')]
# ------------------------------
# [('국제', 'Noun'), ('특송', 'Noun'), ('/', 'Punctuation'), ('E', 'Alpha'), ('-', 'Punctuation'), ('Commerce', 'Alpha'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('글로벌', 'Noun'), ('네트워크', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('배송', 'Noun'), ('이', 'Josa'), ('안되요', 'Adjective'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('채용', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('정수기', 'Noun'), ('이전', 'Noun'), ('설치', 'Noun'), ('창', 'Noun'), ('이', 'Josa'), ('없어요', 'Adjective'), ('\n', 'Foreign')]
# ------------------------------
# [('정수기', 'Noun'), ('설치', 'Noun'), ('서비스', 'Noun'), ('예약', 'Noun'), ('하려고하는데', 'Verb'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('세탁기', 'Noun'), ('를', 'Josa'), ('조금', 'Noun'), ('옮겼는데', 'Verb'), ('그냥', 'Noun'), ('사용', 'Noun'), ('해도', 'Verb'), ('될까', 'Verb'), ('요', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('전자제품', 'Noun'), ('설치', 'Noun'), ('및', 'Noun'), ('이전', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('정수기', 'Noun'), ('철거', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('Best', 'Alpha'), ('Practice', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('Customer', 'Alpha'), ('goods', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('Electronics', 'Alpha'), ('&', 'Punctuation'), ('Hi', 'Alpha'), ('-', 'Punctuation'), ('Tech', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('Construction', 'Alpha'), ('&', 'Punctuation'), ('Machinery', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('Chemical', 'Alpha'), ('&', 'Punctuation'), ('Oil', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('아니오', 'Adjective'), ('\n', 'Foreign')]
# ------------------------------
# [('Best', 'Alpha'), ('Practice', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('통관', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('Customer', 'Alpha'), ('goods', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('수출', 'Noun'), ('물류', 'Noun'), ('상담', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('철도', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('수출', 'Noun'), ('물류', 'Noun'), ('상담', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('전자제품', 'Noun'), ('설치', 'Noun'), ('물류', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('전화번호', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('배송', 'Noun'), ('조회', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('아니오', 'Adjective'), ('\n', 'Foreign')]
# ------------------------------
# [('시스템', 'Noun'), ('링크', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('tracking', 'Alpha'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('북미', 'Noun'), ('지역', 'Noun'), ('사무소', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('냉장고', 'Noun'), ('이전', 'Noun'), ('설치', 'Noun'), ('사다리', 'Noun'), ('차', 'Noun'), ('비용', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('이', 'Determiner'), ('전', 'Modifier'), ('설치', 'Noun'), ('를', 'Josa'), ('카드', 'Noun'), ('로', 'Josa'), ('접수', 'Noun'), ('를', 'Josa'), ('했는데', 'Verb'), ('결재', 'Noun'), ('는', 'Josa'), ('지금', 'Noun'), ('할수', 'Verb'), ('없나요', 'Adjective'), ('?', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [[('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')], [('메일', 'Noun'), ('\n', 'Foreign')], [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')], [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')], [('한국', 'Noun'), ('글로벌', 'Noun'), ('네트워크', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')], [('글로벌', 'Noun'), ('네트워크', 'Noun'), ('\n', 'Foreign')], [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')], [('오산', 'Noun'), ('센터', 'Noun'), ('\n', 'Foreign')], [('국제', 'Noun'), ('특송', 'Noun'), ('/', 'Punctuation'), ('E', 'Alpha'), ('-', 'Punctuation'), ('Commerce', 'Alpha'), ('안내', 'Noun'), ('\n', 'Foreign')], [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')], [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')], [('Construction', 'Alpha'), ('&', 'Punctuation'), ('Machinery', 'Alpha'), ('\n', 'Foreign')], [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')], [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')], [('해상', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')], [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')], [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')], [('물류', 'Noun'), ('SCM', 'Alpha'), ('컨설팅', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')], [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')], [('철거', 'Noun'), ('만', 'Josa'), ('신청', 'Noun'), ('하면', 'Verb'), ('아파트', 'Noun'), ('주차장', 'Noun'), ('으로', 'Josa'), ('내려주나요', 'Verb'), ('?', 'Punctuation'), ('\n', 'Foreign')], [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')], [('산업', 'Noun'), ('군', 'Suffix'), ('카테고리', 'Noun'), ('\n', 'Foreign')], [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')], [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')], [('철거', 'Noun'), ('만', 'Josa'), ('신청', 'Noun'), ('하면', 'Verb'), ('아파트', 'Noun'), ('주차장', 'Noun'), ('으로', 'Josa'), ('내려주나요', 'Verb'), ('?', 'Punctuation'), ('\n', 'Foreign')], [('건조기', 'Noun'), ('이전', 'Noun'), ('설치', 'Noun'), ('비용', 'Noun'), ('\n', 'Foreign')], [('예', 'Noun'), ('\n', 'Foreign')], [('해상', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')], [('사업', 'Noun'), ('영역', 'Noun'), ('\n', 'Foreign')], [('판', 'Noun'), ('토스', 'Noun'), ('성장', 'Noun'), ('과정', 'Noun'), ('\n', 'Foreign')], [('이전', 'Noun'), ('설치', 'Noun'), ('\n', 'Foreign')], [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')], [('e', 'Alpha'), ('판', 'Noun'), ('토스', 'Noun'), ('\n', 'Foreign')], [('송장', 'Noun'), ('\n', 'Foreign')], [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')], [('브라켓', 'Noun'), ('이', 'Josa'), ('없습니다', 'Adjective'), ('\n', 'Foreign')], [('32', 'Number'), ('LK', 'Alpha'), ('562', 'Number'), ('BENA', 'Alpha'), ('스탠드', 'Noun'), ('형', 'Suffix'), ('을', 'Josa'), ('새로', 'Adjective'), ('샀는데', 'Verb'), ('벽', 'Noun'), ('걸이', 'Noun'), ('로', 'Josa'), ('걸수있나요', 'Verb'), ('\n', 'Foreign')], [('배송', 'Noun'), ('조회', 'Noun'), ('\n', 'Foreign')], [('회사', 'Noun'), ('소개', 'Noun'), ('\n', 'Foreign')], [('채용', 'Noun'), ('페이지', 'Noun'), ('\n', 'Foreign')], [('면접', 'Noun'), ('관', 'Noun'), ('\n', 'Foreign')], [('IT', 'Alpha'), ('솔루션', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')], [('채용', 'Noun'), ('페이지', 'Noun'), ('\n', 'Foreign')], [('배송', 'Noun'), ('조회', 'Noun'), ('\n', 'Foreign')], [('채용', 'Noun'), ('페이지', 'Noun'), ('\n', 'Foreign')], [('배송', 'Noun'), ('조회', 'Noun'), ('\n', 'Foreign')], [('배송', 'Noun'), ('조회', 'Noun'), ('\n', 'Foreign')], [('PLIHQ', 'Alpha'), ('2', 'Number'), ('A', 'Alpha'), ('18674', 'Number'), ('\n', 'Foreign')], [('lg', 'Alpha'), ('전자', 'Noun'), ('이전', 'Noun'), ('\n', 'Foreign')], [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')], [('채용', 'Noun'), ('페이지', 'Noun'), ('\n', 'Foreign')], [('해상', 'Noun'), ('운송', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')], [('업무', 'Noun'), ('별', 'Noun'), ('카테고리', 'Noun'), ('\n', 'Foreign')], [('영업', 'Noun'), ('담당자', 'Noun'), ('연락처', 'Noun'), ('\n', 'Foreign')], [('항공', 'Noun'), ('운송', 'Noun'), ('안내 ...
# 1221

# %%
# 5. 명사 혹은 형용사인 품사만 선별해 리스트에 담기
noun_adj_list = []
for sentence1 in sentences_tag:
    for word, tag in sentence1:
        if tag in ['Noun', 'Adjective']:
            noun_adj_list.append(word)

# %%
# 6. 선별된 품사별 빈도수 계산 & 상위 빈도 10까지 출력
counts = Counter(noun_adj_list)
print(counts.most_common(100))
# Out:
# [('문의', 158), ('카테고리', 134), ('안내', 131), ('영업', 117), ('연락처', 117), ('기타', 117), ('담당자', 116), ('업무', 90), ('별', 90), ('회사', 78), ('소개', 76), ('설치', 75), ('글로벌', 64), ('네트워크', 64), ('운송', 57), ('예', 49), ('이전', 47), ('산업', 44), ('채용', 39), ('물류', 32), ('해상', 29), ('솔루션', 29), ('배송', 27), ('페이지', 27), ('항공', 26), ('조회', 24), ('정수기', 23), ('비용', 20), ('전자제품', 19), ('사업', 18), ('영역', 18), ('통관', 18), ('판', 17), ('토스', 17), ('안녕하세요', 16), ('아니오', 15), ('전자', 13), ('국제', 11), ('특송', 10), ('신청', 10), ('철거', 9), ('유럽', 9), ('컨설팅', 8), ('벽', 8), ('세탁기', 8), ('시스템', 8), ('냉장고', 8), ('걸이', 7), ('중국', 7), ('프로젝트', 7), ('어떻게', 7), ('및', 7), ('이사', 6), ('궁금합니다', 6), ('미국', 6), ('아시아', 6), ('하나요', 6), ('링크', 6), ('스타', 6), ('한국', 5), ('센터', 5), ('건조기', 5), ('식기세척기', 5), ('대해', 5), ('화물', 5), ('서비스', 5), ('고객', 5), ('에어컨', 5), ('엘지', 5), ('연봉', 5), ('철도', 4), ('얼마', 4), ('인도네시아', 4), ('회원', 4), ('가입', 4), ('차', 4), ('챗봇', 4), ('베네룩스', 4), ('사', 4), ('사례', 4), ('말레이시아', 4), ('얼마나', 4), ('뭐', 4), ('수출', 4), ('송장', 3), ('컨테이너', 3), ('트롬', 3), ('너', 3), ('자카르타', 3), ('이메일', 3), ('해외', 3), ('시간', 3), ('추가', 3), ('북미', 3), ('가전', 3), ('사다리', 3), ('배', 3), ('점', 3), ('방법', 3), ('조직', 3)]

# %%
df_a = counts.most_common(100)
df = pd.DataFrame(df_a)
#column 부분수정1
df.rename(columns={0:"word",1:"count"}, inplace = True) #False이면 아무변화 없음

df.plot.bar(x='word', y='count', rot=0)
df.to_csv("d:/result.csv", header = True, index = False, encoding='ms949')

#font_path = 'C:/Windows/Fonts/EBS훈민정음R.ttf
#font_path = 'C:/Users/user/AppData/Local/Continuum/anaconda364/Lib/site-packages\pytagcloud/fonts/NotoSansCJKkr-Medium.otf'
#fontprop = fm.FontProperties(fname=font_path, size=18)

#plt.ylabel('빈도', fontproperties=fontprop)

#plt.bar(df["word"],df["count"], width = 1, color = "blue")
#plt.title("Chatbot word counter")
#plt.show()
#df


# 빈도수 시각화하기
#df.plot(kind='barh',title='Chatbot word counter')

# 내림차순 정렬
#df.sort_values(by='count', ascending=False).plot(kind='barh',title='Chatbot word counter')
#df.show()

####################################################
# get_tags 새함수 만듦:
# 기능 1. 댓글별로 명사만 추출
# 기능 2. 명사 빈도수 집계
# 기능 3. 단어구름에 표시할 명사에 3가지 시각화 속성
#        (색상'color', 단어'tag', 크기'size')부여

# 입력변수- text : 댓글, ntags : 표시할 단어수, multiplier : 크기가중치

# %%
def get_tags(text, ntags=20, multiplier=1):
    t = Okt()
    nouns = []
    
# 모든 댓글에서 명사만 추출하고, nouns변수에 누적해 저장함

    for sentence in text:
        for noun in t.nouns(sentence):
            nouns.append(noun)
            #각 명사별로 빈도 계산
            count = Counter(nouns)
    # n:명사, c:빈도
    return [{'color':color(), 'tag':n, 'size':c*multiplier} for n,c in count.most_common(ntags)]

# %%
# draw_cloud 새함수 만듦:
def draw_cloud(tags, filename, fontname = 'Noto Sans CJK',size1 = (1920,1024)):
    pytagcloud.create_tag_image(tags,filename,fontname=fontname,size=size1)
    # 저장된 단어구름 이미지파일(wc1.png)을 내 컴퓨터에 띄움
    webbrowser.open(filename)

####################################################
# 명사에 적용할 색상 랜덤지정
r = lambda: random.randint(0, 255)
color = lambda: (r(), r(), r())

# 옥자 댓글(okja1.txt) 읽기 전용으로 읽어들임.
okjak = []
file = open('d:/april.txt', 'r', encoding ='utf-8')
lines = file.readlines()

for line in lines:
    okjak.append(line)
file.close()

####################################################
# 댓글 명사추출 및 빈도분석(get_tags) 실시
tags = get_tags(okjak)
print(tags)
# 관심명사 단어구름 이미지 파일 저장 및 출력하기
draw_cloud(tags,'d:/wc1.png')
# Out:
# [{'color': (57, 235, 212), 'tag': '문의', 'size': 158}, {'color': (106, 178, 234), 'tag': '카테고리', 'size': 134}, {'color': (19, 92, 206), 'tag': '안내', 'size': 131}, {'color': (248, 79, 217), 'tag': '영업', 'size': 117}, {'color': (121, 115, 12), 'tag': '연락처', 'size': 117}, {'color': (28, 61, 221), 'tag': '기타', 'size': 117}, {'color': (247, 181, 183), 'tag': '담당자', 'size': 116}, {'color': (86, 160, 49), 'tag': '업무', 'size': 90}, {'color': (16, 20, 157), 'tag': '별', 'size': 90}, {'color': (130, 15, 206), 'tag': '회사', 'size': 78}, {'color': (64, 174, 82), 'tag': '소개', 'size': 76}, {'color': (134, 66, 175), 'tag': '설치', 'size': 75}, {'color': (242, 12, 110), 'tag': '글로벌', 'size': 64}, {'color': (93, 220, 255), 'tag': '네트워크', 'size': 64}, {'color': (39, 149, 10), 'tag': '운송', 'size': 57}, {'color': (241, 21, 117), 'tag': '예', 'size': 49}, {'color': (163, 4, 72), 'tag': '이전', 'size': 47}, {'color': (215, 193, 133), 'tag': '산업', 'size': 44}, {'color': (50, 254, 175), 'tag': '채용', 'size': 39}, {'color': (0, 51, 243), 'tag': '물류', 'size': 32}]
