# %%
import pytagcloud
import random

import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns

#노트북에 그래프를 그리기 위해
# %matplotlib inline

#그래프 마이너스 폰트 깨지는 문제 대처
mpl.rcParams['axes.unicode_minus'] = False

#그래프 한글 폰트 깨지는 문제 대처
# path = 'C:/Windows/Fonts/NanumGothic.ttf'
path = 'C:/Windows/Fonts/LGSmHaR.ttf'
font_name = fm.FontProperties(fname=path, size=50).get_name()
font = {'family' : font_name,
        'size'   : 16}
plt.rc('font', **font)
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import webbrowser

# %%
from konlpy.tag import Okt

# %%
from collections import Counter

# %%
file = open('d:/chatbot_log.txt','r',encoding='utf-8')

# %%
lines = file.readlines()

# %%
okja = []

# %%
for line in lines:
    okja.append(line)

# %%
file.close()

# %%
# 3. 트윗터 패키지 안에 konlpy 모듈호출

# %%
twitter = Okt()

# %%
# 4. 각 문장별로 형태소 구분하기
sentences_tag = []
for sentence in okja:
    morph = twitter.pos(sentence)
    sentences_tag.append(morph)
    print(morph)
    print('-'*30)

print(sentences_tag)
print(len(sentences_tag))
print('\n'*3)
# Out:
# [('송장', 'Noun'), ('번호', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('송장', 'Noun'), ('번호', 'Noun'), ('배송', 'Noun'), ('추적', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('배송', 'Noun'), ('조회', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('기타', 'Noun'), ('문의', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('설치', 'Noun'), ('신청', 'Noun'), ('을', 'Josa'), ('했는데', 'Verb'), ('내일', 'Noun'), ('이', 'Josa'), ('이', 'Determiner'), ('전', 'Modifier'), ('예', 'Modifier'), ('악날', 'Noun'), ('인데', 'Josa'), ('언', 'Modifier'), ('저', 'Modifier'), ('쯤', 'Noun'), ('기사', 'Noun'), ('닝', 'Noun'), ('ㅁ', 'KoreanParticle'), ('한', 'Determiner'), ('테', 'Noun'), ('연락', 'Noun'), ('이', 'Josa'), ('오는', 'Modifier'), ('건가', 'Noun'), ('요', 'Josa'), ('?', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('LG', 'Alpha'), ('전자제품', 'Noun'), ('설치', 'Noun'), ('안내', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# ...

# %%
# 5. 명사 혹은 형용사인 품사만 선별해 리스트에 담기
noun_adj_list = []
for sentence1 in sentences_tag:
    for word, tag in sentence1:
        if tag in ['Noun', 'Adjective']:
            noun_adj_list.append(word)

# %%
# 6. 선별된 품사별 빈도수 계산 & 상위 빈도 10까지 출력
counts = Counter(noun_adj_list)
print(counts.most_common(500))
# Out:
# [('안내', 362), ('설치', 348), ('전자제품', 251), ('문의', 134), ('담당자', 125), ('카테고리', 121), ('연락처', 120), ('영업', 116), ('기타', 101), ('네트워크', 94), ('글로벌', 93), ('업무', 87), ('별', 85), ('이전', 71), ('예', 68), ('회사', 60), ('소개', 59), ('운송', 53), ('산업', 37), ('사업', 29), ('물류', 28), ('채용', 27), ('영역', 26), ('정수기', 26), ('배송', 24), ('페이지', 24), ('아니오', 23), ('해상', 22), ('중국', 21), ('솔루션', 21), ('냉장고', 21), ('에어컨', 21), ('판', 20), ('비용', 20), ('조회', 19), ('시스템', 19), ('토스', 19), ('링크', 18), ('항공', 18), ('사', 18), ('고객', 16), ('사례', 15), ('안녕하세요', 15), ('벽', 14), ('걸이', 14), ('철거', 13), ('지역', 12), ('및', 12), ('국제', 11), ('특송', 11), ('통관', 11), ('한국', 11), ('유럽', 10), ('이사', 10), ('창고', 10), ('신청', 9), ('접수', 9), ('있나요', 9), ('예약', 8), ('건조기', 8), ('세탁기', 8), ('뭐', 7), ('법인', 7), ('비', 7), ('남미', 7), ('식기세척기', 7), ('운영', 7), ('스타', 7), ('요', 6), ('컨설팅', 6), ('브라질', 6), ('정도', 6), ('설치시', 6), ('엘지', 6), ('철도', 5), ('이동', 5), ('가전', 5), ('수거', 5), ('견적', 5), ('티비', 5), ('주소', 5), ('어떻게', 5), ('얼마', 5), 
# ...

# %%
def check_delete(x = '예'):
    s = delete_words.str.match(x)
    for index,i in s.items():
        print(i)
        if i == True :
            return True
    return False

# %%
df_b = counts.most_common(30)

df_b = pd.DataFrame(df_b)
df_b.rename(columns={0:"word",1:"count"}, inplace = True) #False이면 아무변화 없음
delete_words = pd.Series(['업무', '예','아니오', '산업', '영역', '서비스','별', '카테고리', '문의', '안내', '기타', '소개', '물류', '페이지', '판', '토스'])

# %%
df_b['delete_yn'] = df_b['word'].map(lambda x : check_delete(x))
df_b = df_b[~df_b['delete_yn'] == True]
df_b.head()
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# ...

# %%
plt.figure(figsize=(20,8))
sns.barplot(x="word", y="count",  data=df_b)
plt.title("챗봇 문의 단어 빈도수")
plt.show()

# %%
df_a = counts.most_common(500)

df = pd.DataFrame(df_a)

#column 부분수정1
df.rename(columns={0:"word",1:"count"}, inplace = True) #False이면 아무변화 없음

df['delete_yn'] = df['word'].map(lambda x : check_delete(x))
df = df[~df['delete_yn'] == True]

# df.plot.bar(x='word', y='count', rot=0)
df.to_csv("d:/chatbot_log_result.csv", header = True, index = False, encoding='ms949')

#font_path = 'C:/Windows/Fonts/EBS훈민정음R.ttf
#font_path = 'C:/Users/user/AppData/Local/Continuum/anaconda364/Lib/site-packages\pytagcloud/fonts/NotoSansCJKkr-Medium.otf'
#fontprop = fm.FontProperties(fname=font_path, size=18)

#plt.ylabel('빈도', fontproperties=fontprop)

#plt.bar(df["word"],df["count"], width = 1, color = "blue")
#plt.title("Chatbot word counter")
#plt.show()
#df


# 빈도수 시각화하기
#df.plot(kind='barh',title='Chatbot word counter')

# 내림차순 정렬
#df.sort_values(by='count', ascending=False).plot(kind='barh',title='Chatbot word counter')
#df.show()

####################################################
# get_tags 새함수 만듦:
# 기능 1. 댓글별로 명사만 추출
# 기능 2. 명사 빈도수 집계
# 기능 3. 단어구름에 표시할 명사에 3가지 시각화 속성
#        (색상'color', 단어'tag', 크기'size')부여

# 입력변수- text : 댓글, ntags : 표시할 단어수, multiplier : 크기가중치
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# ...

# %%
def get_tags(text, ntags=30, multiplier=0.5):
    t = Okt()
    nouns = []
    
# 모든 댓글에서 명사만 추출하고, nouns변수에 누적해 저장함

    for sentence in text:
        for noun in t.nouns(sentence):
            nouns.append(noun)
            #각 명사별로 빈도 계산
            count = Counter(nouns)
    # n:명사, c:빈도
    return [{'color':color(), 'tag':n, 'size':int(c*multiplier)} for n,c in count.most_common(ntags)]

# %%
# draw_cloud 새함수 만듦:
def draw_cloud(tags, filename, fontname = 'Noto Sans CJK',size1 = (1024,768)):
    pytagcloud.create_tag_image(tags,filename,fontname=fontname,size=size1)
    # 저장된 단어구름 이미지파일(wc1.png)을 내 컴퓨터에 띄움
    webbrowser.open(filename)

####################################################
# 명사에 적용할 색상 랜덤지정
r = lambda: random.randint(0, 255)
color = lambda: (r(), r(), r())

# 옥자 댓글(okja1.txt) 읽기 전용으로 읽어들임.
okjak = []
file = open('d:/may.txt', 'r', encoding ='utf-8')
lines = file.readlines()

for line in lines:
    okjak.append(line)
file.close()

####################################################
# 댓글 명사추출 및 빈도분석(get_tags) 실시
tags = get_tags(okjak, 100)
print(tags)
# 관심명사 단어구름 이미지 파일 저장 및 출력하기
df_c = pd.DataFrame(tags)
df_c['delete_yn'] = df_c['tag'].map(lambda x : check_delete(x))
df_c = df_c[~df_c['delete_yn'] == True]
df_c = df_c.drop(columns = ['delete_yn'])
df_c = df_c.to_dict('records')
draw_cloud(df_c,'d:/wc2.png')
# Out:
# [{'color': (250, 100, 58), 'tag': '문의', 'size': 107}, {'color': (85, 6, 28), 'tag': '안내', 'size': 102}, {'color': (106, 155, 250), 'tag': '설치', 'size': 88}, {'color': (171, 141, 20), 'tag': '기타', 'size': 83}, {'color': (185, 41, 239), 'tag': '담당자', 'size': 62}, {'color': (92, 229, 143), 'tag': '카테고리', 'size': 60}, {'color': (84, 82, 51), 'tag': '연락처', 'size': 56}, {'color': (9, 156, 207), 'tag': '영업', 'size': 56}, {'color': (119, 186, 188), 'tag': '전자제품', 'size': 46}, {'color': (30, 176, 73), 'tag': '소개', 'size': 43}, {'color': (151, 238, 104), 'tag': '업무', 'size': 42}, {'color': (177, 147, 219), 'tag': '별', 'size': 42}, {'color': (210, 7, 35), 'tag': '회사', 'size': 41}, {'color': (76, 32, 83), 'tag': '예', 'size': 37}, {'color': (60, 78, 227), 'tag': '글로벌', 'size': 35}, {'color': (202, 210, 160), 'tag': '네트워크', 'size': 35}, {'color': (126, 58, 65), 'tag': '운송', 'size': 31}, {'color': (167, 201, 11), 'tag': '이전', 'size': 29}, {'color': (45, 145, 216), 'tag': '물류', 'size': 28}, {'color'
# ...
